# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
import random

# %% [markdown]
# # 3 案例：显示温度变化状况

# %%
# 0. 生成数据
x = range(60)
y = [random.uniform(10,15) for i in x]

# 1. 创建画布
plt.figure(figsize=(20,8),dpi=100)

# 2. 图形绘制
plt.plot(x,y)

# 3. 图像展示
plt.show()

# %%
x_values = list(range(11))
# x轴的数字是0到10这11个整数
y_values=[x**2 for x in x_values]
#y轴的数字是x轴数字的平方
plt.plot(x_values,y_values,c='green')
#用plot函数绘制拆线图，线条颜色设置为绿色
# plt.title('Squares',fontsize=24)
#设置図表标准和标题字号
plt.tick_params(axis='both',which='major',lablesize=14)
#设置刻度的字号
# plt.xlabel('Numbers',fontsize=14)
#设置x轴标签及其字号
# plt.ylabel('Squares',fontsize=14)
#设置y轴标签及其字号
#把x轴的刻度间隔设置为1，并存在变量里
x_major_locator=MultipleLocator(1)
#ax为两条坐标轴的实例
ax = plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
#把x轴的主刻度设置为1的倍数

#把x轴的刻度范围设置为0到11，
plt.xlim(0,11)

plt.show()
#显示图表
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 9
#       5 plt.plot(x_values,y_values,c='green')
#       6 #用plot函数绘制拆线图，线条颜色设置为绿色
#       7 # plt.title('Squares',fontsize=24)
#       8 #设置図表标准和标题字号
# ----> 9 plt.tick_params(axis='both',which='major',lablesize=14)
#      10 #设置刻度的字号
#      11 # plt.xlabel('Numbers',fontsize=14)
#      12 #设置x轴标签及其字号
#      13 # plt.ylabel('Squares',fontsize=14)
#      14 #设置y轴标签及其字号
#      15 #把x轴的刻度间隔设置为1，并存在变量里
#      16 x_major_locator=MultipleLocator(1)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:3948, in tick_params(axis, **kwargs)
#    3946 @_copy_docstring_and_deprecators(Axes.tick_params)
#    3947 def tick_params(axis: Literal["both", "x", "y"] = "both", **kwargs) -> None:
# -> 3948     gca().tick_params(axis=axis, **kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_base.py:3389, in _AxesBase.tick_params(self, axis, **kwargs)
#    3387     xkw.pop('labelleft', None)
#    3388     xkw.pop('labelright', None)
# -> 3389     self.xaxis.set_tick_params(**xkw)
#    3390 if axis in ['y', 'both']:
#    3391     ykw = dict(kwargs)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/matplotlib/axis.py:958, in Axis.set_tick_params(self, which, reset, **kwargs)
#     945 """
#     946 Set appearance parameters for ticks, ticklabels, and gridlines.
#     947
#    (...)
#     955     gridlines.
#     956 """
#     957 _api.check_in_list(['major', 'minor', 'both'], which=which)
# --> 958 kwtrans = self._translate_tick_params(kwargs)
#     960 # the kwargs are stored in self._major/minor_tick_kw so that any
#     961 # future new ticks will automatically get them
#     962 if reset:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/matplotlib/axis.py:1102, in Axis._translate_tick_params(kw, reverse)
#    1100 for key in kw_:
#    1101     if key not in allowed_keys:
# -> 1102         raise ValueError(
#    1103             "keyword %s is not recognized; valid keywords are %s"
#    1104             % (key, allowed_keys))
#    1105 kwtrans.update(kw_)
#    1106 return kwtrans
#
# ValueError: keyword lablesize is not recognized; valid keywords are ['size', 'width', 'color', 'tickdir', 'pad', 'labelsize', 'labelcolor', 'labelfontfamily', 'zorder', 'gridOn', 'tick1On', 'tick2On', 'label1On', 'label2On', 'length', 'direction', 'left', 'bottom', 'right', 'top', 'labelleft', 'labelbottom', 'labelright', 'labeltop', 'labelrotation', 'grid_agg_filter', 'grid_alpha', 'grid_animated', 'grid_antialiased', 'grid_clip_box', 'grid_clip_on', 'grid_clip_path', 'grid_color', 'grid_dash_capstyle', 'grid_dash_joinstyle', 'grid_dashes', 'grid_data', 'grid_drawstyle', 'grid_figure', 'grid_fillstyle', 'grid_gapcolor', 'grid_gid', 'grid_in_layout', 'grid_label', 'grid_linestyle', 'grid_linewidth', 'grid_marker', 'grid_markeredgecolor', 'grid_markeredgewidth', 'grid_markerfacecolor', 'grid_markerfacecoloralt', 'grid_markersize', 'grid_markevery', 'grid_mouseover', 'grid_path_effects', 'grid_picker', 'grid_pickradius', 'grid_rasterized', 'grid_sketch_params', 'grid_snap', 'grid_solid_capstyle', 'grid_solid_joinstyle', 'grid_transform', 'grid_url', 'grid_visible', 'grid_xdata', 'grid_ydata', 'grid_zorder', 'grid_aa', 'grid_c', 'grid_ds', 'grid_ls', 'grid_lw', 'grid_mec', 'grid_mew', 'grid_mfc', 'grid_mfcalt', 'grid_ms']
