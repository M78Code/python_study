# %%
import numpy as np
from matplotlib.pyplot import MultipleLocator
from matplotlib.patches import Polygon
from pylab import mpl
import matplotlib.pyplot as pt

# %%
# 関数の定義
def func(x):
    return x * np.sin(x)

# %%
# xの値の範囲, 60部分を分割する
x = np.linspace(-np.pi, np.pi, 60)
# y関数
y = func(x)

# %%
mpl.matplotlib_fname()
# Out:
# '/home/leon/anaconda3/lib/python3.11/site-packages/matplotlib/mpl-data/matplotlibrc'

# %%
def _draw_fourier_figure():
    # グラフのサイズ　面積12cm * 10cm
    pt.figure(figsize=(12, 10))
    
    # グラフを描く
    pt.plot(x, y, label="f(x)関数の図")
    
    # 軸のラベルとタイトルの設定
    mpl.rcParams["font.family"] = ["SimHei"]  # linux下设置的字体
    mpl.rcParams["axes.unicode_minus"] = False  # "UTF-8"
    pt.xlabel("x")
    pt.ylabel("f(x)")
    ax = pt.gca()
    ax.xaxis.set_major_locator(MultipleLocator(1))
    
    # 図例を示す
    pt.legend()
    
    # グラフを示す
    pt.show()

# %%
_draw_fourier_figure()
# Out:
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# /home/leon/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38306 (\N{CJK UNIFIED IDEOGRAPH-95A2}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/leon/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/leon/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 12398 (\N{HIRAGANA LETTER NO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/leon/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22259 (\N{CJK UNIFIED IDEOGRAPH-56F3}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
# findfont: Font family 'Arial Unicode MS' not found.
